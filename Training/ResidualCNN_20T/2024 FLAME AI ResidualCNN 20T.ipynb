# %%
import numpy as np
import random
import torch
from torch.utils.data import DataLoader, Dataset, Subset

random.seed(428)
np.random.seed(428)
torch.use_deterministic_algorithms(True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(428)
torch.cuda.manual_seed(428)
torch.cuda.manual_seed_all(428)
def seed_worker(worker_id):
    np.random.seed(torch.initial_seed() % 2**32)    
    random.seed(torch.initial_seed() % 2**32)

# %%
import os
import subprocess
import importlib  # Import importlib

required_packages = ['torch', 'torchvision', 'segmentation-models-pytorch', 'efficientnet_pytorch']

def install_packages(packages):
    for package in packages:
        try:
            # Check if the package is already installed (Python 3.7+)
            importlib.import_module(package)
            print(f"{package} already installed.")
        except ImportError:
            print(f"Installing {package}...")
            subprocess.check_call(['pip', 'install', package])
            print(f"{package} installed successfully.")

install_packages(required_packages)
# Out:
# torch already installed.
# torchvision already installed.
# Installing segmentation-models-pytorch...
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.4-py3-none-any.whl.metadata (30 kB)
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: huggingface-hub>=0.24.6 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.25.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (10.3.0)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (1.16.0)
# Collecting timm==0.9.7 (from segmentation-models-pytorch)
#   Downloading timm-0.9.7-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (0.19.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from segmentation-models-pytorch) (4.66.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.4.0)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation-models-pytorch) (6.0.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm==0.9.7->segmentation-models-pytorch) (0.4.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.24.6->segmentation-models-pytorch) (4.12.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.26.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.24.6->segmentation-models-pytorch) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Downloading segmentation_models_pytorch-0.3.4-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 8.6 MB/s eta 0:00:00
# Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 61.2 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py): started
#   Building wheel for efficientnet-pytorch (setup.py): finished with status 'done'
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16427 sha256=ee0e319a93a2e5a40b7686aa99de37482909d8894a385a61f245fc3068b2c4ba
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
#   Building wheel for pretrainedmodels (setup.py): started
#   Building wheel for pretrainedmodels (setup.py): finished with status 'done'
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=bab5a0e5fe64cf4d1c48a485273481a5960f97c8e41378194a56c7769b26f7a7
#   Stored in directory: /root/.cache/pip/wheels/35/cb/a5/8f534c60142835bfc889f9a482e4a67e0b817032d9c6883b64
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, efficientnet-pytorch, timm, pretrainedmodels, segmentation-models-pytorch
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.9
#     Uninstalling timm-1.0.9:
#       Successfully uninstalled timm-1.0.9
# Successfully installed efficientnet-pytorch-0.7.1 munch-4.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.4 timm-0.9.7
# segmentation-models-pytorch installed successfully.
# efficientnet_pytorch already installed.

# %%
train_csv = '/kaggle/input/2024-flame-ai-challenge/dataset/train.csv'
train_data_dir = '/kaggle/input/2024-flame-ai-challenge/dataset/train'
test_csv = '/kaggle/input/2024-flame-ai-challenge/dataset/test.csv'
test_data_dir = '/kaggle/input/2024-flame-ai-challenge/dataset/test'

SEQ_LEN = 5
seq_len = SEQ_LEN
NUM_STEPS = 20
batch_size = 4
#num_epochs = 1

# Configuration Parameters
use_early_stopping = False  # Set to False to disable early stopping
patience = 5      # Number of epochs to wait for improvement
delta = 0     # Minimum change to qualify as improvement

# Define Model Names
model_names = [
#    'unet',
#    'deeplabtemporal',
#   'resnet50',
#    'convlstm',
    'residualcnn',
#    'residualcnnsa',
#    'residualdensecnn',
#    'dconvlstmsac',
#    'selfattconvlstm',
#    'bidirectconvlstmunet',
#    #'pinn-convlstm',
#     '3dconvlstm',
#    'convlstm_autoencoder',
#    'stconvlstm_autoencoder',
#    'spatiotemporal_transformer',
#    'attentionunet',
#    'tcnmodel',
#    'hybridcnntransformer',
#    'multiscaleconvlstm',
]

# Define default number of epochs
num_epochs_default = 1

# Update model_epochs to include all models or rely on the default
model_epochs = {
#     'unet': 100,
#     'deeplabtemporal': 5,
#      'resnet50': 50,
#      'convlstm': 50,
      'residualcnn': 400,
#     'residualcnnsa': 60,
#      'dconvlstmsac': 30,
#      'selfattconvlstm': 50,
#      'bidirectconvlstmunet': 50,
#      'pinn-convlstm': 30,
#      '3dconvlstm': 30,
#     'convlstm_autoencoder': 30,
#     'stconvlstm_autoencoder': 30,
#     'spatiotemporal_transformer': 30  
#     'attentionunet': 50,
#     'tcnmodel': 50,
#     'hybridcnntransformer': 50,
#     'residualdensecnn': 50,
#     'multiscaleconvlstm': 40,
}

# %%
# 1. Import Necessary Libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import (
    resnet18, resnet34, resnet50, resnet101, resnet152,
    ResNet18_Weights, ResNet34_Weights, ResNet50_Weights, ResNet101_Weights, ResNet152_Weights,
    densenet121, DenseNet121_Weights,
    mobilenet_v2, MobileNet_V2_Weights
)
from efficientnet_pytorch import EfficientNet  # Ensure this is installed
from torch.utils.data import DataLoader, Dataset, Subset
import pandas as pd
import numpy as np
import os
import torchvision.ops as ops  # For DeformConv2d
import segmentation_models_pytorch as smp

# Try importing MobileNetV3 from timm
try:
    import timm
    has_timm = True
except ImportError:
    has_timm = False
    print("timm library not found. MobileNetV3 will not be available. Please install it using `pip install timm`.")

# %%
class FireDataset(Dataset):
    def __init__(self, csv_data, data_dir, seq_len=5, multi_step=20, is_train=True):
        """
        Args:
            csv_data (str or DataFrame): Path to the CSV file or a pandas DataFrame.
            data_dir (str): Directory containing the .dat files.
            seq_len (int): Number of past timesteps to use as input.
            multi_step (int): Number of future timesteps to predict.
            is_train (bool): Flag indicating training or testing mode.
        """
        if isinstance(csv_data, str):
            self.data_info = pd.read_csv(csv_data)
        else:
            self.data_info = csv_data  # Accept DataFrame directly
        
        self.data_dir = data_dir
        self.seq_len = seq_len
        self.multi_step = multi_step
        self.is_train = is_train
        self.samples = self._create_samples()

    def _create_samples(self):
        samples = []
        for _, row in self.data_info.iterrows():
            id = row['id']
            u = row['u']
            alpha = row['alpha']
            Nt = row['Nt']
            # Load filenames
            theta_path = os.path.join(self.data_dir, row['theta_filename'])
            ustar_path = os.path.join(self.data_dir, row['ustar_filename'])
            xi_path = os.path.join(self.data_dir, row['xi_filename'])

            # Check if files exist
            if not os.path.exists(theta_path) or not os.path.exists(ustar_path) or not os.path.exists(xi_path):
                print(f"Missing files for ID {id}. Skipping.")
                continue

            # Load .dat files (assuming binary format)
            try:
                theta = np.fromfile(theta_path, dtype=np.float32).reshape(Nt, 113, 32)
                ustar = np.fromfile(ustar_path, dtype=np.float32).reshape(Nt, 113, 32)
                xi = np.fromfile(xi_path, dtype=np.float32).reshape(Nt, 113, 32)
            except ValueError as e:
                print(f"Error reshaping files for ID {id}: {e}")
                continue

            if self.is_train:
                # Ensure there are enough timesteps to create at least one sample
                required_timesteps = self.seq_len + self.multi_step
                if Nt < required_timesteps:
                    print(f"Not enough timesteps for ID {id}. Required: {required_timesteps}, Available: {Nt}")
                    continue

                # Create multiple samples using rolling window with step size NUM_STEPS - SEQ_LEN (15)
                #step_size = NUM_STEPS - self.seq_len  # 15
                step_size = 1

                for t in range(0, Nt - self.seq_len - self.multi_step + 1, step_size):
                    # Input sequences: theta, ustar, xi for seq_len timesteps
                    theta_seq = theta[t:t+self.seq_len]  # Shape: [seq_len, 113,32]
                    ustar_seq = ustar[t:t+self.seq_len]
                    xi_seq = xi[t:t+self.seq_len]

                    # Target sequences: xi for multi_step timesteps
                    target_seq = xi[t+self.seq_len:t+self.seq_len + self.multi_step]  # Shape: [multi_step, 113,32]

                    # Stack features per time step: [seq_len, 5, 113,32]
                    features = []
                    for i in range(self.seq_len):
                        theta_i = theta_seq[i]  # [113,32]
                        ustar_i = ustar_seq[i]
                        xi_i = xi_seq[i]
                        u_i = u
                        alpha_i = alpha

                        # Convert scalar features to tensors and tile
                        u_tensor = torch.tensor(u_i, dtype=torch.float32).unsqueeze(0).unsqueeze(1).repeat(1, 113, 32)  # [1,113,32]
                        alpha_tensor = torch.tensor(alpha_i, dtype=torch.float32).unsqueeze(0).unsqueeze(1).repeat(1, 113, 32)  # [1,113,32]

                        # Stack all features
                        feature = torch.stack([
                            torch.tensor(ustar_i, dtype=torch.float32),  # [113,32]
                            torch.tensor(theta_i, dtype=torch.float32),  # [113,32]
                            torch.tensor(xi_i, dtype=torch.float32),     # [113,32]
                            u_tensor.squeeze(0),                        # [113,32]
                            alpha_tensor.squeeze(0)                     # [113,32]
                        ], dim=0)  # [5,113,32]

                        features.append(feature)
                    
                    feature_sequence = torch.stack(features, dim=0)  # [seq_len, 5, 113,32]

                    # Target is the next multi_step xi timesteps
                    target = torch.tensor(target_seq, dtype=torch.float32)  # [multi_step,113,32]

                    samples.append({
                        'id': id,
                        'input': feature_sequence,  # [5,5,113,32]
                        'target': target  # [20,113,32]
                    })
            else:
                # For test set, you might not have targets, or handle similarly
                if Nt < self.seq_len:
                    print(f"Not enough timesteps for ID {id} in test set. Required: {self.seq_len}, Available: {Nt}")
                    continue

                theta_seq = theta[:self.seq_len]
                ustar_seq = ustar[:self.seq_len]
                xi_seq = xi[:self.seq_len]

                # Stack features per time step: [seq_len, 5, 113,32]
                features = []
                for i in range(self.seq_len):
                    theta_i = theta_seq[i]  # [113,32]
                    ustar_i = ustar_seq[i]
                    xi_i = xi_seq[i]
                    u_i = u
                    alpha_i = alpha

                    # Convert scalar features to tensors and tile
                    u_tensor = torch.tensor(u_i, dtype=torch.float32).unsqueeze(0).unsqueeze(1).repeat(1, 113, 32)  # [1,113,32]
                    alpha_tensor = torch.tensor(alpha_i, dtype=torch.float32).unsqueeze(0).unsqueeze(1).repeat(1, 113, 32)  # [1,113,32]

                    # Stack all features
                    feature = torch.stack([
                        torch.tensor(ustar_i, dtype=torch.float32),  # [113,32]
                        torch.tensor(theta_i, dtype=torch.float32),  # [113,32]
                        torch.tensor(xi_i, dtype=torch.float32),     # [113,32]
                        u_tensor.squeeze(0),                        # [113,32]
                        alpha_tensor.squeeze(0)                     # [113,32]
                    ], dim=0)  # [5,113,32]

                    features.append(feature)
                
                feature_sequence = torch.stack(features, dim=0)  # [seq_len, 5, 113,32]

                samples.append({
                    'id': id,
                    'input': feature_sequence,  # [5,5,113,32]
                    'target': None  # No target for test set
                })

        return samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]
        if self.is_train:
            return sample['input'], sample['target']  # [3,5,113,32], [1,113,32]
        else:
            return sample['input']  # Return only the input for the test set

# %%
class ResidualBlock(nn.Module):
    """
    Simplified Residual Block with a single convolution layer and skip connection.
    """
    def __init__(self, channels, kernel_size=3, padding=1, activation=nn.ReLU(inplace=True)):
        super(ResidualBlock, self).__init__()
        self.activation = activation
        self.conv = nn.Conv2d(channels, channels, kernel_size=kernel_size, padding=padding, stride=1, bias=False)
        self.bn = nn.BatchNorm2d(channels)

    def forward(self, x):
        identity = x  # Skip connection
        out = self.conv(x)
        out = self.bn(out)
        out += identity  # Add skip connection
        out = self.activation(out)
        return out

class ResidualCNN(nn.Module):
    """
    Residual CNN tailored for multi-step forecasting.
    """
    def __init__(self, in_channels=25, num_residual_blocks=4, out_channels=1, num_steps=20, kernel_size=3, padding=1, activation=nn.ReLU(inplace=True)):
        super(ResidualCNN, self).__init__()
        self.num_steps = num_steps
        self.activation = activation
        self.initial_conv = nn.Conv2d(in_channels, in_channels, kernel_size=kernel_size, stride=1, padding=padding, bias=False)
        self.bn = nn.BatchNorm2d(in_channels)

        # Residual blocks
        self.residual_blocks = nn.Sequential(*[
            ResidualBlock(in_channels, kernel_size=kernel_size, padding=padding, activation=activation)
            for _ in range(num_residual_blocks)
        ])

        # Output convolution layer modified to output num_steps
        self.output_conv = nn.Conv2d(in_channels, out_channels * num_steps, kernel_size=1, stride=1, padding=0, bias=True)

    def forward(self, x):
        """
        Forward pass for ResidualCNN.

        Args:
            x (Tensor): Input tensor of shape [batch_size, seq_len, 5, 113, 32].

        Returns:
            Tensor: Output tensor of shape [batch_size, num_steps, out_channels, 113, 32].
        """
        batch_size, seq_len, channels, height, width = x.size()
        x = x.view(batch_size, seq_len * channels, height, width)  # [batch_size, 25, 113, 32]

        out = self.initial_conv(x)  # [batch_size, 25, 113, 32]
        out = self.bn(out)
        out = self.activation(out)

        out = self.residual_blocks(out)  # [batch_size, 25, 113, 32]
        out = self.output_conv(out)      # [batch_size, 20, 113, 32] assuming num_steps=20

        # Reshape to [batch_size, num_steps, out_channels, 113, 32]
        out = out.view(batch_size, self.num_steps, -1, height, width)

        return out

# %%
def train_model(
    model, 
    train_loader, 
    val_loader, 
    criterion, 
    optimizer, 
    num_epochs, 
    device, 
    model_save_path
):
    """
    Trains the model and saves the best model based on validation loss.

    Args:
        model (nn.Module): The model to train.
        train_loader (DataLoader): DataLoader for training data.
        val_loader (DataLoader): DataLoader for validation data.
        criterion (nn.Module): Loss function.
        optimizer (torch.optim.Optimizer): Optimizer.
        num_epochs (int): Number of epochs to train.
        device (torch.device): Device to train on.
        model_save_path (str): Path to save the best model.

    Returns:
        model (nn.Module): The trained model loaded with the best weights.
        best_val_loss (float): The best validation loss achieved.
    """
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        print(f"\nEpoch {epoch+1}/{num_epochs} - Training")
        for inputs, targets in train_loader:
            inputs = inputs.to(device)        # [batch_size, 5, 5, 113,32]
            targets = targets.to(device)      # [batch_size, 20,113,32]
#             print(f"Input shape: {inputs.shape}")    # Should be [batch_size, 5, 5, 113, 32]
#             print(f"Target shape: {targets.shape}")  # Should be [batch_size, 20, 113, 32]

            optimizer.zero_grad()
            outputs = model(inputs)           # [batch_size, 20,1,113,32]

            # Compute multi-step loss
            # Adjust targets shape to match outputs by adding channel dimension
            loss = criterion(outputs, targets.unsqueeze(2))  # [batch_size, 20,1,113,32]
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        epoch_train_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1} Training Loss: {epoch_train_loss:.4f}")

        # Validation phase
        model.eval()
        val_loss = 0.0

        #print(f"Epoch {epoch+1} Validation")
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs = inputs.to(device)        # [batch_size, 5, 5, 113,32]
                targets = targets.to(device)      # [batch_size, 20,113,32]

                outputs = model(inputs)           # [batch_size, 20,1,113,32]
                loss = criterion(outputs, targets.unsqueeze(2))  # [batch_size, 20,1,113,32]
                val_loss += loss.item() * inputs.size(0)

        epoch_val_loss = val_loss / len(val_loader.dataset)
        print(f"Epoch {epoch+1} Validation Loss: {epoch_val_loss:.4f}")

        # Save the model if validation loss has decreased
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            torch.save(model.state_dict(), model_save_path)
            print(f"Validation loss decreased. Saving model to {model_save_path}")
        else:
            print("Validation loss did not improve.")

    # Load the best model
    model.load_state_dict(torch.load(model_save_path))
    print(f"\nTraining complete. Best Validation Loss: {best_val_loss:.4f}")
    return model, best_val_loss

# %%
from tqdm import tqdm

# 12. Create Training Dataset and Define Folds
df_train = pd.read_csv(train_csv)
simulations = df_train['id'].unique()
num_folds = len(simulations)  # 9 folds

# Shuffle simulations for randomness
np.random.seed(42)
shuffled_simulations = np.random.permutation(simulations)

# Assign each simulation to a fold (one simulation per fold)
folds = []
for sim in shuffled_simulations:
    folds.append([sim])  # Each fold has one simulation

criterion = nn.MSELoss()
saved_model_paths = []
fold_val_losses = {}
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
for fold_idx, val_simulations in enumerate(folds):
    print(f'\nFold {fold_idx+1}/{num_folds}')
    
    val_mask = df_train['id'].isin(val_simulations)
    train_mask = ~val_mask
    
    print(f"\nFold {fold_idx + 1} - Validation 'id's:")
    print(df_train.loc[val_mask, 'id'].unique())  # Print unique IDs in validation set

    print(f"\nFold {fold_idx + 1} - Train 'id's:")
    print(df_train.loc[train_mask, 'id'].unique())  # Print unique IDs in training set

    # Create training and validation subsets
    train_subset = FireDataset(df_train[train_mask], train_data_dir, seq_len=seq_len, multi_step=NUM_STEPS, is_train=True)
    val_subset = FireDataset(df_train[val_mask], train_data_dir, seq_len=seq_len, multi_step=NUM_STEPS, is_train=True)


    print(f'Training samples: {len(train_subset)}')
    print(f'Validation samples: {len(val_subset)}')

    # Create DataLoaders
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True, worker_init_fn=seed_worker)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True, worker_init_fn=seed_worker)

    # For each model
    for encoder_name in model_names:
        print(f'\nTraining model with encoder {encoder_name}')
        if encoder_name == 'residualcnn':
            model = ResidualCNN(
            in_channels=SEQ_LEN * 5,  # 5 channels per timestep
            num_residual_blocks=4,
            out_channels=1,
            num_steps=NUM_STEPS,
            kernel_size=3,
            padding=1,
            activation=nn.ReLU(inplace=True)
        ).to(device)
        
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

        # Define model save path
        model_save_path = f'model_{encoder_name}_fold{fold_idx+1}.pth'
        
        # Retrieve num_epochs for the current model
        current_num_epochs = model_epochs.get(encoder_name, num_epochs_default)  # Fallback to default num_epochs if not specified
        print(f"Training {encoder_name} for {current_num_epochs}")

        # Train the model with Early Stopping
        model, best_val_loss = train_model(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            criterion=criterion,
            optimizer=optimizer,
            num_epochs=current_num_epochs,
            device=device,
            model_save_path=model_save_path,
        )
        
        fold_val_losses[(fold_idx + 1, encoder_name)] = best_val_loss
        
        # Append the model save path
        saved_model_paths.append(model_save_path)

# Print average score for each fold and across all models
for fold_idx in range(num_folds):
    fold_losses = [loss for (fold, model), loss in fold_val_losses.items() if fold == fold_idx + 1]
    avg_fold_loss = np.mean(fold_losses) if fold_losses else 0.0  # Handle potential empty list
    print(f"Fold {fold_idx+1} Average Validation Loss: {avg_fold_loss:.4f}")

# Calculate and print overall average validation loss across all folds and models
overall_avg_loss = np.mean(list(fold_val_losses.values()))
print(f"Overall Average Validation Loss: {overall_avg_loss:.4f}")
# Out:
# Fold 1/9
#
# Fold 1 - Validation 'id's:
# [808631]
#
# Fold 1 - Train 'id's:
# [804025 875935 930086 661713 633229 868570  16525 220212]
# Training samples: 1008
# Validation samples: 126
#
# Training model with encoder residualcnn
# Training residualcnn for 400
#
# Epoch 1/400 - Training
# Epoch 1 Training Loss: 0.2592
# Epoch 1 Validation Loss: 0.0858
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 2/400 - Training
# Epoch 2 Training Loss: 0.0523
# Epoch 2 Validation Loss: 0.0406
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 3/400 - Training
# Epoch 3 Training Loss: 0.0315
# Epoch 3 Validation Loss: 0.0310
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 4/400 - Training
# Epoch 4 Training Loss: 0.0266
# Epoch 4 Validation Loss: 0.0287
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 5/400 - Training
# Epoch 5 Training Loss: 0.0244
# Epoch 5 Validation Loss: 0.0316
# Validation loss did not improve.
#
# Epoch 6/400 - Training
# Epoch 6 Training Loss: 0.0219
# Epoch 6 Validation Loss: 0.0263
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 7/400 - Training
# Epoch 7 Training Loss: 0.0202
# Epoch 7 Validation Loss: 0.0306
# Validation loss did not improve.
#
# Epoch 8/400 - Training
# Epoch 8 Training Loss: 0.0192
# Epoch 8 Validation Loss: 0.0232
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 9/400 - Training
# Epoch 9 Training Loss: 0.0184
# Epoch 9 Validation Loss: 0.0225
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 10/400 - Training
# Epoch 10 Training Loss: 0.0178
# Epoch 10 Validation Loss: 0.0234
# Validation loss did not improve.
#
# Epoch 11/400 - Training
# Epoch 11 Training Loss: 0.0171
# Epoch 11 Validation Loss: 0.0239
# Validation loss did not improve.
#
# Epoch 12/400 - Training
# Epoch 12 Training Loss: 0.0165
# Epoch 12 Validation Loss: 0.0209
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 13/400 - Training
# Epoch 13 Training Loss: 0.0160
# Epoch 13 Validation Loss: 0.0212
# Validation loss did not improve.
#
# Epoch 14/400 - Training
# Epoch 14 Training Loss: 0.0154
# Epoch 14 Validation Loss: 0.0232
# Validation loss did not improve.
#
# Epoch 15/400 - Training
# Epoch 15 Training Loss: 0.0149
# Epoch 15 Validation Loss: 0.0278
# Validation loss did not improve.
#
# Epoch 16/400 - Training
# Epoch 16 Training Loss: 0.0146
# Epoch 16 Validation Loss: 0.0216
# Validation loss did not improve.
#
# Epoch 17/400 - Training
# Epoch 17 Training Loss: 0.0143
# Epoch 17 Validation Loss: 0.0209
# Validation loss did not improve.
#
# Epoch 18/400 - Training
# Epoch 18 Training Loss: 0.0140
# Epoch 18 Validation Loss: 0.0244
# Validation loss did not improve.
#
# Epoch 19/400 - Training
# Epoch 19 Training Loss: 0.0139
# Epoch 19 Validation Loss: 0.0352
# Validation loss did not improve.
#
# Epoch 20/400 - Training
# Epoch 20 Training Loss: 0.0136
# Epoch 20 Validation Loss: 0.0193
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 21/400 - Training
# Epoch 21 Training Loss: 0.0135
# Epoch 21 Validation Loss: 0.0184
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 22/400 - Training
# Epoch 22 Training Loss: 0.0133
# Epoch 22 Validation Loss: 0.0198
# Validation loss did not improve.
#
# Epoch 23/400 - Training
# Epoch 23 Training Loss: 0.0131
# Epoch 23 Validation Loss: 0.0197
# Validation loss did not improve.
#
# Epoch 24/400 - Training
# Epoch 24 Training Loss: 0.0130
# Epoch 24 Validation Loss: 0.0186
# Validation loss did not improve.
#
# Epoch 25/400 - Training
# Epoch 25 Training Loss: 0.0128
# Epoch 25 Validation Loss: 0.0173
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 26/400 - Training
# Epoch 26 Training Loss: 0.0127
# Epoch 26 Validation Loss: 0.0215
# Validation loss did not improve.
#
# Epoch 27/400 - Training
# Epoch 27 Training Loss: 0.0127
# Epoch 27 Validation Loss: 0.0208
# Validation loss did not improve.
#
# Epoch 28/400 - Training
# Epoch 28 Training Loss: 0.0125
# Epoch 28 Validation Loss: 0.0180
# Validation loss did not improve.
#
# Epoch 29/400 - Training
# Epoch 29 Training Loss: 0.0124
# Epoch 29 Validation Loss: 0.0207
# Validation loss did not improve.
#
# Epoch 30/400 - Training
# Epoch 30 Training Loss: 0.0124
# Epoch 30 Validation Loss: 0.0213
# Validation loss did not improve.
#
# Epoch 31/400 - Training
# Epoch 31 Training Loss: 0.0123
# Epoch 31 Validation Loss: 0.0167
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 32/400 - Training
# Epoch 32 Training Loss: 0.0122
# Epoch 32 Validation Loss: 0.0172
# Validation loss did not improve.
#
# Epoch 33/400 - Training
# Epoch 33 Training Loss: 0.0121
# Epoch 33 Validation Loss: 0.0179
# Validation loss did not improve.
#
# Epoch 34/400 - Training
# Epoch 34 Training Loss: 0.0120
# Epoch 34 Validation Loss: 0.0171
# Validation loss did not improve.
#
# Epoch 35/400 - Training
# Epoch 35 Training Loss: 0.0120
# Epoch 35 Validation Loss: 0.0179
# Validation loss did not improve.
#
# Epoch 36/400 - Training
# Epoch 36 Training Loss: 0.0120
# Epoch 36 Validation Loss: 0.0162
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 37/400 - Training
# Epoch 37 Training Loss: 0.0119
# Epoch 37 Validation Loss: 0.0174
# Validation loss did not improve.
#
# Epoch 38/400 - Training
# Epoch 38 Training Loss: 0.0119
# Epoch 38 Validation Loss: 0.0180
# Validation loss did not improve.
#
# Epoch 39/400 - Training
# Epoch 39 Training Loss: 0.0119
# Epoch 39 Validation Loss: 0.0194
# Validation loss did not improve.
#
# Epoch 40/400 - Training
# Epoch 40 Training Loss: 0.0118
# Epoch 40 Validation Loss: 0.0250
# Validation loss did not improve.
#
# Epoch 41/400 - Training
# Epoch 41 Training Loss: 0.0117
# Epoch 41 Validation Loss: 0.0187
# Validation loss did not improve.
#
# Epoch 42/400 - Training
# Epoch 42 Training Loss: 0.0117
# Epoch 42 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 43/400 - Training
# Epoch 43 Training Loss: 0.0117
# Epoch 43 Validation Loss: 0.0158
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 44/400 - Training
# Epoch 44 Training Loss: 0.0116
# Epoch 44 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 45/400 - Training
# Epoch 45 Training Loss: 0.0116
# Epoch 45 Validation Loss: 0.0200
# Validation loss did not improve.
#
# Epoch 46/400 - Training
# Epoch 46 Training Loss: 0.0116
# Epoch 46 Validation Loss: 0.0188
# Validation loss did not improve.
#
# Epoch 47/400 - Training
# Epoch 47 Training Loss: 0.0115
# Epoch 47 Validation Loss: 0.0193
# Validation loss did not improve.
#
# Epoch 48/400 - Training
# Epoch 48 Training Loss: 0.0116
# Epoch 48 Validation Loss: 0.0188
# Validation loss did not improve.
#
# Epoch 49/400 - Training
# Epoch 49 Training Loss: 0.0115
# Epoch 49 Validation Loss: 0.0264
# Validation loss did not improve.
#
# Epoch 50/400 - Training
# Epoch 50 Training Loss: 0.0115
# Epoch 50 Validation Loss: 0.0179
# Validation loss did not improve.
#
# Epoch 51/400 - Training
# Epoch 51 Training Loss: 0.0114
# Epoch 51 Validation Loss: 0.0163
# Validation loss did not improve.
#
# Epoch 52/400 - Training
# Epoch 52 Training Loss: 0.0114
# Epoch 52 Validation Loss: 0.0193
# Validation loss did not improve.
#
# Epoch 53/400 - Training
# Epoch 53 Training Loss: 0.0114
# Epoch 53 Validation Loss: 0.0263
# Validation loss did not improve.
#
# Epoch 54/400 - Training
# Epoch 54 Training Loss: 0.0113
# Epoch 54 Validation Loss: 0.0182
# Validation loss did not improve.
#
# Epoch 55/400 - Training
# Epoch 55 Training Loss: 0.0114
# Epoch 55 Validation Loss: 0.0183
# Validation loss did not improve.
#
# Epoch 56/400 - Training
# Epoch 56 Training Loss: 0.0114
# Epoch 56 Validation Loss: 0.0155
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 57/400 - Training
# Epoch 57 Training Loss: 0.0113
# Epoch 57 Validation Loss: 0.0182
# Validation loss did not improve.
#
# Epoch 58/400 - Training
# Epoch 58 Training Loss: 0.0112
# Epoch 58 Validation Loss: 0.0163
# Validation loss did not improve.
#
# Epoch 59/400 - Training
# Epoch 59 Training Loss: 0.0112
# Epoch 59 Validation Loss: 0.0190
# Validation loss did not improve.
#
# Epoch 60/400 - Training
# Epoch 60 Training Loss: 0.0112
# Epoch 60 Validation Loss: 0.0154
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 61/400 - Training
# Epoch 61 Training Loss: 0.0112
# Epoch 61 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 62/400 - Training
# Epoch 62 Training Loss: 0.0112
# Epoch 62 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 63/400 - Training
# Epoch 63 Training Loss: 0.0111
# Epoch 63 Validation Loss: 0.0158
# Validation loss did not improve.
#
# Epoch 64/400 - Training
# Epoch 64 Training Loss: 0.0112
# Epoch 64 Validation Loss: 0.0163
# Validation loss did not improve.
#
# Epoch 65/400 - Training
# Epoch 65 Training Loss: 0.0112
# Epoch 65 Validation Loss: 0.0205
# Validation loss did not improve.
#
# Epoch 66/400 - Training
# Epoch 66 Training Loss: 0.0111
# Epoch 66 Validation Loss: 0.0194
# Validation loss did not improve.
#
# Epoch 67/400 - Training
# Epoch 67 Training Loss: 0.0111
# Epoch 67 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 68/400 - Training
# Epoch 68 Training Loss: 0.0111
# Epoch 68 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 69/400 - Training
# Epoch 69 Training Loss: 0.0111
# Epoch 69 Validation Loss: 0.0179
# Validation loss did not improve.
#
# Epoch 70/400 - Training
# Epoch 70 Training Loss: 0.0110
# Epoch 70 Validation Loss: 0.0157
# Validation loss did not improve.
#
# Epoch 71/400 - Training
# Epoch 71 Training Loss: 0.0111
# Epoch 71 Validation Loss: 0.0182
# Validation loss did not improve.
#
# Epoch 72/400 - Training
# Epoch 72 Training Loss: 0.0111
# Epoch 72 Validation Loss: 0.0197
# Validation loss did not improve.
#
# Epoch 73/400 - Training
# Epoch 73 Training Loss: 0.0110
# Epoch 73 Validation Loss: 0.0206
# Validation loss did not improve.
#
# Epoch 74/400 - Training
# Epoch 74 Training Loss: 0.0110
# Epoch 74 Validation Loss: 0.0150
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 75/400 - Training
# Epoch 75 Training Loss: 0.0109
# Epoch 75 Validation Loss: 0.0175
# Validation loss did not improve.
#
# Epoch 76/400 - Training
# Epoch 76 Training Loss: 0.0110
# Epoch 76 Validation Loss: 0.0165
# Validation loss did not improve.
#
# Epoch 77/400 - Training
# Epoch 77 Training Loss: 0.0110
# Epoch 77 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 78/400 - Training
# Epoch 78 Training Loss: 0.0109
# Epoch 78 Validation Loss: 0.0184
# Validation loss did not improve.
#
# Epoch 79/400 - Training
# Epoch 79 Training Loss: 0.0110
# Epoch 79 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 80/400 - Training
# Epoch 80 Training Loss: 0.0109
# Epoch 80 Validation Loss: 0.0187
# Validation loss did not improve.
#
# Epoch 81/400 - Training
# Epoch 81 Training Loss: 0.0109
# Epoch 81 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 82/400 - Training
# Epoch 82 Training Loss: 0.0109
# Epoch 82 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 83/400 - Training
# Epoch 83 Training Loss: 0.0109
# Epoch 83 Validation Loss: 0.0218
# Validation loss did not improve.
#
# Epoch 84/400 - Training
# Epoch 84 Training Loss: 0.0108
# Epoch 84 Validation Loss: 0.0160
# Validation loss did not improve.
#
# Epoch 85/400 - Training
# Epoch 85 Training Loss: 0.0109
# Epoch 85 Validation Loss: 0.0187
# Validation loss did not improve.
#
# Epoch 86/400 - Training
# Epoch 86 Training Loss: 0.0108
# Epoch 86 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 87/400 - Training
# Epoch 87 Training Loss: 0.0109
# Epoch 87 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 88/400 - Training
# Epoch 88 Training Loss: 0.0108
# Epoch 88 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 89/400 - Training
# Epoch 89 Training Loss: 0.0108
# Epoch 89 Validation Loss: 0.0173
# Validation loss did not improve.
#
# Epoch 90/400 - Training
# Epoch 90 Training Loss: 0.0108
# Epoch 90 Validation Loss: 0.0201
# Validation loss did not improve.
#
# Epoch 91/400 - Training
# Epoch 91 Training Loss: 0.0108
# Epoch 91 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 92/400 - Training
# Epoch 92 Training Loss: 0.0108
# Epoch 92 Validation Loss: 0.0171
# Validation loss did not improve.
#
# Epoch 93/400 - Training
# Epoch 93 Training Loss: 0.0107
# Epoch 93 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 94/400 - Training
# Epoch 94 Training Loss: 0.0107
# Epoch 94 Validation Loss: 0.0176
# Validation loss did not improve.
#
# Epoch 95/400 - Training
# Epoch 95 Training Loss: 0.0107
# Epoch 95 Validation Loss: 0.0142
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 96/400 - Training
# Epoch 96 Training Loss: 0.0107
# Epoch 96 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 97/400 - Training
# Epoch 97 Training Loss: 0.0107
# Epoch 97 Validation Loss: 0.0161
# Validation loss did not improve.
#
# Epoch 98/400 - Training
# Epoch 98 Training Loss: 0.0107
# Epoch 98 Validation Loss: 0.0182
# Validation loss did not improve.
#
# Epoch 99/400 - Training
# Epoch 99 Training Loss: 0.0107
# Epoch 99 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 100/400 - Training
# Epoch 100 Training Loss: 0.0107
# Epoch 100 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 101/400 - Training
# Epoch 101 Training Loss: 0.0107
# Epoch 101 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 102/400 - Training
# Epoch 102 Training Loss: 0.0107
# Epoch 102 Validation Loss: 0.0176
# Validation loss did not improve.
#
# Epoch 103/400 - Training
# Epoch 103 Training Loss: 0.0107
# Epoch 103 Validation Loss: 0.0261
# Validation loss did not improve.
#
# Epoch 104/400 - Training
# Epoch 104 Training Loss: 0.0107
# Epoch 104 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 105/400 - Training
# Epoch 105 Training Loss: 0.0107
# Epoch 105 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 106/400 - Training
# Epoch 106 Training Loss: 0.0107
# Epoch 106 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 107/400 - Training
# Epoch 107 Training Loss: 0.0106
# Epoch 107 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 108/400 - Training
# Epoch 108 Training Loss: 0.0106
# Epoch 108 Validation Loss: 0.0140
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 109/400 - Training
# Epoch 109 Training Loss: 0.0106
# Epoch 109 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 110/400 - Training
# Epoch 110 Training Loss: 0.0106
# Epoch 110 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 111/400 - Training
# Epoch 111 Training Loss: 0.0106
# Epoch 111 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 112/400 - Training
# Epoch 112 Training Loss: 0.0107
# Epoch 112 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 113/400 - Training
# Epoch 113 Training Loss: 0.0106
# Epoch 113 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 114/400 - Training
# Epoch 114 Training Loss: 0.0106
# Epoch 114 Validation Loss: 0.0178
# Validation loss did not improve.
#
# Epoch 115/400 - Training
# Epoch 115 Training Loss: 0.0106
# Epoch 115 Validation Loss: 0.0138
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 116/400 - Training
# Epoch 116 Training Loss: 0.0106
# Epoch 116 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 117/400 - Training
# Epoch 117 Training Loss: 0.0106
# Epoch 117 Validation Loss: 0.0175
# Validation loss did not improve.
#
# Epoch 118/400 - Training
# Epoch 118 Training Loss: 0.0106
# Epoch 118 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 119/400 - Training
# Epoch 119 Training Loss: 0.0105
# Epoch 119 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 120/400 - Training
# Epoch 120 Training Loss: 0.0106
# Epoch 120 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 121/400 - Training
# Epoch 121 Training Loss: 0.0105
# Epoch 121 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 122/400 - Training
# Epoch 122 Training Loss: 0.0105
# Epoch 122 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 123/400 - Training
# Epoch 123 Training Loss: 0.0105
# Epoch 123 Validation Loss: 0.0187
# Validation loss did not improve.
#
# Epoch 124/400 - Training
# Epoch 124 Training Loss: 0.0105
# Epoch 124 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 125/400 - Training
# Epoch 125 Training Loss: 0.0105
# Epoch 125 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 126/400 - Training
# Epoch 126 Training Loss: 0.0105
# Epoch 126 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 127/400 - Training
# Epoch 127 Training Loss: 0.0105
# Epoch 127 Validation Loss: 0.0172
# Validation loss did not improve.
#
# Epoch 128/400 - Training
# Epoch 128 Training Loss: 0.0105
# Epoch 128 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 129/400 - Training
# Epoch 129 Training Loss: 0.0105
# Epoch 129 Validation Loss: 0.0190
# Validation loss did not improve.
#
# Epoch 130/400 - Training
# Epoch 130 Training Loss: 0.0105
# Epoch 130 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 131/400 - Training
# Epoch 131 Training Loss: 0.0104
# Epoch 131 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 132/400 - Training
# Epoch 132 Training Loss: 0.0105
# Epoch 132 Validation Loss: 0.0178
# Validation loss did not improve.
#
# Epoch 133/400 - Training
# Epoch 133 Training Loss: 0.0105
# Epoch 133 Validation Loss: 0.0139
# Validation loss did not improve.
#
# Epoch 134/400 - Training
# Epoch 134 Training Loss: 0.0105
# Epoch 134 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 135/400 - Training
# Epoch 135 Training Loss: 0.0105
# Epoch 135 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 136/400 - Training
# Epoch 136 Training Loss: 0.0104
# Epoch 136 Validation Loss: 0.0170
# Validation loss did not improve.
#
# Epoch 137/400 - Training
# Epoch 137 Training Loss: 0.0104
# Epoch 137 Validation Loss: 0.0193
# Validation loss did not improve.
#
# Epoch 138/400 - Training
# Epoch 138 Training Loss: 0.0104
# Epoch 138 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 139/400 - Training
# Epoch 139 Training Loss: 0.0104
# Epoch 139 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 140/400 - Training
# Epoch 140 Training Loss: 0.0104
# Epoch 140 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 141/400 - Training
# Epoch 141 Training Loss: 0.0104
# Epoch 141 Validation Loss: 0.0183
# Validation loss did not improve.
#
# Epoch 142/400 - Training
# Epoch 142 Training Loss: 0.0104
# Epoch 142 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 143/400 - Training
# Epoch 143 Training Loss: 0.0104
# Epoch 143 Validation Loss: 0.0169
# Validation loss did not improve.
#
# Epoch 144/400 - Training
# Epoch 144 Training Loss: 0.0104
# Epoch 144 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 145/400 - Training
# Epoch 145 Training Loss: 0.0104
# Epoch 145 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 146/400 - Training
# Epoch 146 Training Loss: 0.0104
# Epoch 146 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 147/400 - Training
# Epoch 147 Training Loss: 0.0104
# Epoch 147 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 148/400 - Training
# Epoch 148 Training Loss: 0.0104
# Epoch 148 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 149/400 - Training
# Epoch 149 Training Loss: 0.0103
# Epoch 149 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 150/400 - Training
# Epoch 150 Training Loss: 0.0104
# Epoch 150 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 151/400 - Training
# Epoch 151 Training Loss: 0.0104
# Epoch 151 Validation Loss: 0.0183
# Validation loss did not improve.
#
# Epoch 152/400 - Training
# Epoch 152 Training Loss: 0.0103
# Epoch 152 Validation Loss: 0.0168
# Validation loss did not improve.
#
# Epoch 153/400 - Training
# Epoch 153 Training Loss: 0.0103
# Epoch 153 Validation Loss: 0.0168
# Validation loss did not improve.
#
# Epoch 154/400 - Training
# Epoch 154 Training Loss: 0.0103
# Epoch 154 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 155/400 - Training
# Epoch 155 Training Loss: 0.0103
# Epoch 155 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 156/400 - Training
# Epoch 156 Training Loss: 0.0103
# Epoch 156 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 157/400 - Training
# Epoch 157 Training Loss: 0.0103
# Epoch 157 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 158/400 - Training
# Epoch 158 Training Loss: 0.0103
# Epoch 158 Validation Loss: 0.0138
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 159/400 - Training
# Epoch 159 Training Loss: 0.0103
# Epoch 159 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 160/400 - Training
# Epoch 160 Training Loss: 0.0103
# Epoch 160 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 161/400 - Training
# Epoch 161 Training Loss: 0.0103
# Epoch 161 Validation Loss: 0.0195
# Validation loss did not improve.
#
# Epoch 162/400 - Training
# Epoch 162 Training Loss: 0.0103
# Epoch 162 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 163/400 - Training
# Epoch 163 Training Loss: 0.0103
# Epoch 163 Validation Loss: 0.0136
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 164/400 - Training
# Epoch 164 Training Loss: 0.0103
# Epoch 164 Validation Loss: 0.0140
# Validation loss did not improve.
#
# Epoch 165/400 - Training
# Epoch 165 Training Loss: 0.0103
# Epoch 165 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 166/400 - Training
# Epoch 166 Training Loss: 0.0103
# Epoch 166 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 167/400 - Training
# Epoch 167 Training Loss: 0.0103
# Epoch 167 Validation Loss: 0.0164
# Validation loss did not improve.
#
# Epoch 168/400 - Training
# Epoch 168 Training Loss: 0.0102
# Epoch 168 Validation Loss: 0.0136
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 169/400 - Training
# Epoch 169 Training Loss: 0.0103
# Epoch 169 Validation Loss: 0.0157
# Validation loss did not improve.
#
# Epoch 170/400 - Training
# Epoch 170 Training Loss: 0.0103
# Epoch 170 Validation Loss: 0.0135
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 171/400 - Training
# Epoch 171 Training Loss: 0.0103
# Epoch 171 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 172/400 - Training
# Epoch 172 Training Loss: 0.0102
# Epoch 172 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 173/400 - Training
# Epoch 173 Training Loss: 0.0103
# Epoch 173 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 174/400 - Training
# Epoch 174 Training Loss: 0.0102
# Epoch 174 Validation Loss: 0.0140
# Validation loss did not improve.
#
# Epoch 175/400 - Training
# Epoch 175 Training Loss: 0.0102
# Epoch 175 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 176/400 - Training
# Epoch 176 Training Loss: 0.0102
# Epoch 176 Validation Loss: 0.0204
# Validation loss did not improve.
#
# Epoch 177/400 - Training
# Epoch 177 Training Loss: 0.0102
# Epoch 177 Validation Loss: 0.0144
# Validation loss did not improve.
#
# Epoch 178/400 - Training
# Epoch 178 Training Loss: 0.0103
# Epoch 178 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 179/400 - Training
# Epoch 179 Training Loss: 0.0102
# Epoch 179 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 180/400 - Training
# Epoch 180 Training Loss: 0.0102
# Epoch 180 Validation Loss: 0.0182
# Validation loss did not improve.
#
# Epoch 181/400 - Training
# Epoch 181 Training Loss: 0.0102
# Epoch 181 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 182/400 - Training
# Epoch 182 Training Loss: 0.0102
# Epoch 182 Validation Loss: 0.0162
# Validation loss did not improve.
#
# Epoch 183/400 - Training
# Epoch 183 Training Loss: 0.0102
# Epoch 183 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 184/400 - Training
# Epoch 184 Training Loss: 0.0102
# Epoch 184 Validation Loss: 0.0165
# Validation loss did not improve.
#
# Epoch 185/400 - Training
# Epoch 185 Training Loss: 0.0102
# Epoch 185 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 186/400 - Training
# Epoch 186 Training Loss: 0.0102
# Epoch 186 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 187/400 - Training
# Epoch 187 Training Loss: 0.0102
# Epoch 187 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 188/400 - Training
# Epoch 188 Training Loss: 0.0102
# Epoch 188 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 189/400 - Training
# Epoch 189 Training Loss: 0.0102
# Epoch 189 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 190/400 - Training
# Epoch 190 Training Loss: 0.0102
# Epoch 190 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 191/400 - Training
# Epoch 191 Training Loss: 0.0102
# Epoch 191 Validation Loss: 0.0161
# Validation loss did not improve.
#
# Epoch 192/400 - Training
# Epoch 192 Training Loss: 0.0101
# Epoch 192 Validation Loss: 0.0179
# Validation loss did not improve.
#
# Epoch 193/400 - Training
# Epoch 193 Training Loss: 0.0101
# Epoch 193 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 194/400 - Training
# Epoch 194 Training Loss: 0.0101
# Epoch 194 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 195/400 - Training
# Epoch 195 Training Loss: 0.0101
# Epoch 195 Validation Loss: 0.0139
# Validation loss did not improve.
#
# Epoch 196/400 - Training
# Epoch 196 Training Loss: 0.0102
# Epoch 196 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 197/400 - Training
# Epoch 197 Training Loss: 0.0101
# Epoch 197 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 198/400 - Training
# Epoch 198 Training Loss: 0.0101
# Epoch 198 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 199/400 - Training
# Epoch 199 Training Loss: 0.0102
# Epoch 199 Validation Loss: 0.0197
# Validation loss did not improve.
#
# Epoch 200/400 - Training
# Epoch 200 Training Loss: 0.0102
# Epoch 200 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 201/400 - Training
# Epoch 201 Training Loss: 0.0101
# Epoch 201 Validation Loss: 0.0132
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 202/400 - Training
# Epoch 202 Training Loss: 0.0101
# Epoch 202 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 203/400 - Training
# Epoch 203 Training Loss: 0.0101
# Epoch 203 Validation Loss: 0.0139
# Validation loss did not improve.
#
# Epoch 204/400 - Training
# Epoch 204 Training Loss: 0.0101
# Epoch 204 Validation Loss: 0.0162
# Validation loss did not improve.
#
# Epoch 205/400 - Training
# Epoch 205 Training Loss: 0.0101
# Epoch 205 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 206/400 - Training
# Epoch 206 Training Loss: 0.0101
# Epoch 206 Validation Loss: 0.0173
# Validation loss did not improve.
#
# Epoch 207/400 - Training
# Epoch 207 Training Loss: 0.0101
# Epoch 207 Validation Loss: 0.0134
# Validation loss did not improve.
#
# Epoch 208/400 - Training
# Epoch 208 Training Loss: 0.0101
# Epoch 208 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 209/400 - Training
# Epoch 209 Training Loss: 0.0101
# Epoch 209 Validation Loss: 0.0139
# Validation loss did not improve.
#
# Epoch 210/400 - Training
# Epoch 210 Training Loss: 0.0101
# Epoch 210 Validation Loss: 0.0165
# Validation loss did not improve.
#
# Epoch 211/400 - Training
# Epoch 211 Training Loss: 0.0101
# Epoch 211 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 212/400 - Training
# Epoch 212 Training Loss: 0.0101
# Epoch 212 Validation Loss: 0.0132
# Validation loss decreased. Saving model to model_residualcnn_fold1.pth
#
# Epoch 213/400 - Training
# Epoch 213 Training Loss: 0.0101
# Epoch 213 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 214/400 - Training
# Epoch 214 Training Loss: 0.0101
# Epoch 214 Validation Loss: 0.0164
# Validation loss did not improve.
#
# Epoch 215/400 - Training
# Epoch 215 Training Loss: 0.0101
# Epoch 215 Validation Loss: 0.0179
# Validation loss did not improve.
#
# Epoch 216/400 - Training
# Epoch 216 Training Loss: 0.0100
# Epoch 216 Validation Loss: 0.0136
# Validation loss did not improve.
#
# Epoch 217/400 - Training
# Epoch 217 Training Loss: 0.0101
# Epoch 217 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 218/400 - Training
# Epoch 218 Training Loss: 0.0101
# Epoch 218 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 219/400 - Training
# Epoch 219 Training Loss: 0.0101
# Epoch 219 Validation Loss: 0.0133
# Validation loss did not improve.
#
# Epoch 220/400 - Training
# Epoch 220 Training Loss: 0.0101
# Epoch 220 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 221/400 - Training
# Epoch 221 Training Loss: 0.0100
# Epoch 221 Validation Loss: 0.0180
# Validation loss did not improve.
#
# Epoch 222/400 - Training
# Epoch 222 Training Loss: 0.0100
# Epoch 222 Validation Loss: 0.0169
# Validation loss did not improve.
#
# Epoch 223/400 - Training
# Epoch 223 Training Loss: 0.0101
# Epoch 223 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 224/400 - Training
# Epoch 224 Training Loss: 0.0100
# Epoch 224 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 225/400 - Training
# Epoch 225 Training Loss: 0.0100
# Epoch 225 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 226/400 - Training
# Epoch 226 Training Loss: 0.0101
# Epoch 226 Validation Loss: 0.0171
# Validation loss did not improve.
#
# Epoch 227/400 - Training
# Epoch 227 Training Loss: 0.0100
# Epoch 227 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 228/400 - Training
# Epoch 228 Training Loss: 0.0100
# Epoch 228 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 229/400 - Training
# Epoch 229 Training Loss: 0.0100
# Epoch 229 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 230/400 - Training
# Epoch 230 Training Loss: 0.0100
# Epoch 230 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 231/400 - Training
# Epoch 231 Training Loss: 0.0100
# Epoch 231 Validation Loss: 0.0158
# Validation loss did not improve.
#
# Epoch 232/400 - Training
# Epoch 232 Training Loss: 0.0100
# Epoch 232 Validation Loss: 0.0169
# Validation loss did not improve.
#
# Epoch 233/400 - Training
# Epoch 233 Training Loss: 0.0100
# Epoch 233 Validation Loss: 0.0180
# Validation loss did not improve.
#
# Epoch 234/400 - Training
# Epoch 234 Training Loss: 0.0100
# Epoch 234 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 235/400 - Training
# Epoch 235 Training Loss: 0.0100
# Epoch 235 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 236/400 - Training
# Epoch 236 Training Loss: 0.0100
# Epoch 236 Validation Loss: 0.0163
# Validation loss did not improve.
#
# Epoch 237/400 - Training
# Epoch 237 Training Loss: 0.0100
# Epoch 237 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 238/400 - Training
# Epoch 238 Training Loss: 0.0100
# Epoch 238 Validation Loss: 0.0162
# Validation loss did not improve.
#
# Epoch 239/400 - Training
# Epoch 239 Training Loss: 0.0100
# Epoch 239 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 240/400 - Training
# Epoch 240 Training Loss: 0.0100
# Epoch 240 Validation Loss: 0.0133
# Validation loss did not improve.
#
# Epoch 241/400 - Training
# Epoch 241 Training Loss: 0.0100
# Epoch 241 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 242/400 - Training
# Epoch 242 Training Loss: 0.0100
# Epoch 242 Validation Loss: 0.0166
# Validation loss did not improve.
#
# Epoch 243/400 - Training
# Epoch 243 Training Loss: 0.0100
# Epoch 243 Validation Loss: 0.0145
# Validation loss did not improve.
#
# Epoch 244/400 - Training
# Epoch 244 Training Loss: 0.0100
# Epoch 244 Validation Loss: 0.0140
# Validation loss did not improve.
#
# Epoch 245/400 - Training
# Epoch 245 Training Loss: 0.0100
# Epoch 245 Validation Loss: 0.0144
# Validation loss did not improve.
#
# Epoch 246/400 - Training
# Epoch 246 Training Loss: 0.0099
# Epoch 246 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 247/400 - Training
# Epoch 247 Training Loss: 0.0100
# Epoch 247 Validation Loss: 0.0134
# Validation loss did not improve.
#
# Epoch 248/400 - Training
# Epoch 248 Training Loss: 0.0099
# Epoch 248 Validation Loss: 0.0158
# Validation loss did not improve.
#
# Epoch 249/400 - Training
# Epoch 249 Training Loss: 0.0099
# Epoch 249 Validation Loss: 0.0162
# Validation loss did not improve.
#
# Epoch 250/400 - Training
# Epoch 250 Training Loss: 0.0099
# Epoch 250 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 251/400 - Training
# Epoch 251 Training Loss: 0.0099
# Epoch 251 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 252/400 - Training
# Epoch 252 Training Loss: 0.0099
# Epoch 252 Validation Loss: 0.0176
# Validation loss did not improve.
#
# Epoch 253/400 - Training
# Epoch 253 Training Loss: 0.0099
# Epoch 253 Validation Loss: 0.0161
# Validation loss did not improve.
#
# Epoch 254/400 - Training
# Epoch 254 Training Loss: 0.0099
# Epoch 254 Validation Loss: 0.0186
# Validation loss did not improve.
#
# Epoch 255/400 - Training
# Epoch 255 Training Loss: 0.0099
# Epoch 255 Validation Loss: 0.0185
# Validation loss did not improve.
#
# Epoch 256/400 - Training
# Epoch 256 Training Loss: 0.0099
# Epoch 256 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 257/400 - Training
# Epoch 257 Training Loss: 0.0099
# Epoch 257 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 258/400 - Training
# Epoch 258 Training Loss: 0.0099
# Epoch 258 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 259/400 - Training
# Epoch 259 Training Loss: 0.0099
# Epoch 259 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 260/400 - Training
# Epoch 260 Training Loss: 0.0099
# Epoch 260 Validation Loss: 0.0170
# Validation loss did not improve.
#
# Epoch 261/400 - Training
# Epoch 261 Training Loss: 0.0099
# Epoch 261 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 262/400 - Training
# Epoch 262 Training Loss: 0.0099
# Epoch 262 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 263/400 - Training
# Epoch 263 Training Loss: 0.0099
# Epoch 263 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 264/400 - Training
# Epoch 264 Training Loss: 0.0099
# Epoch 264 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 265/400 - Training
# Epoch 265 Training Loss: 0.0099
# Epoch 265 Validation Loss: 0.0188
# Validation loss did not improve.
#
# Epoch 266/400 - Training
# Epoch 266 Training Loss: 0.0099
# Epoch 266 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 267/400 - Training
# Epoch 267 Training Loss: 0.0099
# Epoch 267 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 268/400 - Training
# Epoch 268 Training Loss: 0.0099
# Epoch 268 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 269/400 - Training
# Epoch 269 Training Loss: 0.0099
# Epoch 269 Validation Loss: 0.0159
# Validation loss did not improve.
#
# Epoch 270/400 - Training
# Epoch 270 Training Loss: 0.0099
# Epoch 270 Validation Loss: 0.0174
# Validation loss did not improve.
#
# Epoch 271/400 - Training
# Epoch 271 Training Loss: 0.0099
# Epoch 271 Validation Loss: 0.0163
# Validation loss did not improve.
#
# Epoch 272/400 - Training
# Epoch 272 Training Loss: 0.0099
# Epoch 272 Validation Loss: 0.0171
# Validation loss did not improve.
#
# Epoch 273/400 - Training
# Epoch 273 Training Loss: 0.0099
# Epoch 273 Validation Loss: 0.0169
# Validation loss did not improve.
#
# Epoch 274/400 - Training
# Epoch 274 Training Loss: 0.0099
# Epoch 274 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 275/400 - Training
# Epoch 275 Training Loss: 0.0098
# Epoch 275 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 276/400 - Training
# Epoch 276 Training Loss: 0.0099
# Epoch 276 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 277/400 - Training
# Epoch 277 Training Loss: 0.0099
# Epoch 277 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 278/400 - Training
# Epoch 278 Training Loss: 0.0099
# Epoch 278 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 279/400 - Training
# Epoch 279 Training Loss: 0.0098
# Epoch 279 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 280/400 - Training
# Epoch 280 Training Loss: 0.0098
# Epoch 280 Validation Loss: 0.0139
# Validation loss did not improve.
#
# Epoch 281/400 - Training
# Epoch 281 Training Loss: 0.0099
# Epoch 281 Validation Loss: 0.0168
# Validation loss did not improve.
#
# Epoch 282/400 - Training
# Epoch 282 Training Loss: 0.0098
# Epoch 282 Validation Loss: 0.0133
# Validation loss did not improve.
#
# Epoch 283/400 - Training
# Epoch 283 Training Loss: 0.0098
# Epoch 283 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 284/400 - Training
# Epoch 284 Training Loss: 0.0098
# Epoch 284 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 285/400 - Training
# Epoch 285 Training Loss: 0.0098
# Epoch 285 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 286/400 - Training
# Epoch 286 Training Loss: 0.0098
# Epoch 286 Validation Loss: 0.0139
# Validation loss did not improve.
#
# Epoch 287/400 - Training
# Epoch 287 Training Loss: 0.0098
# Epoch 287 Validation Loss: 0.0136
# Validation loss did not improve.
#
# Epoch 288/400 - Training
# Epoch 288 Training Loss: 0.0098
# Epoch 288 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 289/400 - Training
# Epoch 289 Training Loss: 0.0098
# Epoch 289 Validation Loss: 0.0162
# Validation loss did not improve.
#
# Epoch 290/400 - Training
# Epoch 290 Training Loss: 0.0098
# Epoch 290 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 291/400 - Training
# Epoch 291 Training Loss: 0.0098
# Epoch 291 Validation Loss: 0.0168
# Validation loss did not improve.
#
# Epoch 292/400 - Training
# Epoch 292 Training Loss: 0.0098
# Epoch 292 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 293/400 - Training
# Epoch 293 Training Loss: 0.0098
# Epoch 293 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 294/400 - Training
# Epoch 294 Training Loss: 0.0098
# Epoch 294 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 295/400 - Training
# Epoch 295 Training Loss: 0.0098
# Epoch 295 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 296/400 - Training
# Epoch 296 Training Loss: 0.0098
# Epoch 296 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 297/400 - Training
# Epoch 297 Training Loss: 0.0098
# Epoch 297 Validation Loss: 0.0157
# Validation loss did not improve.
#
# Epoch 298/400 - Training
# Epoch 298 Training Loss: 0.0098
# Epoch 298 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 299/400 - Training
# Epoch 299 Training Loss: 0.0098
# Epoch 299 Validation Loss: 0.0164
# Validation loss did not improve.
#
# Epoch 300/400 - Training
# Epoch 300 Training Loss: 0.0098
# Epoch 300 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 301/400 - Training
# Epoch 301 Training Loss: 0.0098
# Epoch 301 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 302/400 - Training
# Epoch 302 Training Loss: 0.0098
# Epoch 302 Validation Loss: 0.0178
# Validation loss did not improve.
#
# Epoch 303/400 - Training
# Epoch 303 Training Loss: 0.0098
# Epoch 303 Validation Loss: 0.0134
# Validation loss did not improve.
#
# Epoch 304/400 - Training
# Epoch 304 Training Loss: 0.0098
# Epoch 304 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 305/400 - Training
# Epoch 305 Training Loss: 0.0098
# Epoch 305 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 306/400 - Training
# Epoch 306 Training Loss: 0.0098
# Epoch 306 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 307/400 - Training
# Epoch 307 Training Loss: 0.0098
# Epoch 307 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 308/400 - Training
# Epoch 308 Training Loss: 0.0098
# Epoch 308 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 309/400 - Training
# Epoch 309 Training Loss: 0.0098
# Epoch 309 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 310/400 - Training
# Epoch 310 Training Loss: 0.0097
# Epoch 310 Validation Loss: 0.0161
# Validation loss did not improve.
#
# Epoch 311/400 - Training
# Epoch 311 Training Loss: 0.0098
# Epoch 311 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 312/400 - Training
# Epoch 312 Training Loss: 0.0098
# Epoch 312 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 313/400 - Training
# Epoch 313 Training Loss: 0.0098
# Epoch 313 Validation Loss: 0.0164
# Validation loss did not improve.
#
# Epoch 314/400 - Training
# Epoch 314 Training Loss: 0.0098
# Epoch 314 Validation Loss: 0.0172
# Validation loss did not improve.
#
# Epoch 315/400 - Training
# Epoch 315 Training Loss: 0.0097
# Epoch 315 Validation Loss: 0.0212
# Validation loss did not improve.
#
# Epoch 316/400 - Training
# Epoch 316 Training Loss: 0.0097
# Epoch 316 Validation Loss: 0.0165
# Validation loss did not improve.
#
# Epoch 317/400 - Training
# Epoch 317 Training Loss: 0.0097
# Epoch 317 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 318/400 - Training
# Epoch 318 Training Loss: 0.0098
# Epoch 318 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 319/400 - Training
# Epoch 319 Training Loss: 0.0097
# Epoch 319 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 320/400 - Training
# Epoch 320 Training Loss: 0.0098
# Epoch 320 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 321/400 - Training
# Epoch 321 Training Loss: 0.0098
# Epoch 321 Validation Loss: 0.0187
# Validation loss did not improve.
#
# Epoch 322/400 - Training
# Epoch 322 Training Loss: 0.0098
# Epoch 322 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 323/400 - Training
# Epoch 323 Training Loss: 0.0097
# Epoch 323 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 324/400 - Training
# Epoch 324 Training Loss: 0.0097
# Epoch 324 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 325/400 - Training
# Epoch 325 Training Loss: 0.0097
# Epoch 325 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 326/400 - Training
# Epoch 326 Training Loss: 0.0097
# Epoch 326 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 327/400 - Training
# Epoch 327 Training Loss: 0.0097
# Epoch 327 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 328/400 - Training
# Epoch 328 Training Loss: 0.0097
# Epoch 328 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 329/400 - Training
# Epoch 329 Training Loss: 0.0097
# Epoch 329 Validation Loss: 0.0145
# Validation loss did not improve.
#
# Epoch 330/400 - Training
# Epoch 330 Training Loss: 0.0097
# Epoch 330 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 331/400 - Training
# Epoch 331 Training Loss: 0.0097
# Epoch 331 Validation Loss: 0.0177
# Validation loss did not improve.
#
# Epoch 332/400 - Training
# Epoch 332 Training Loss: 0.0097
# Epoch 332 Validation Loss: 0.0176
# Validation loss did not improve.
#
# Epoch 333/400 - Training
# Epoch 333 Training Loss: 0.0097
# Epoch 333 Validation Loss: 0.0156
# Validation loss did not improve.
#
# Epoch 334/400 - Training
# Epoch 334 Training Loss: 0.0097
# Epoch 334 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 335/400 - Training
# Epoch 335 Training Loss: 0.0097
# Epoch 335 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 336/400 - Training
# Epoch 336 Training Loss: 0.0097
# Epoch 336 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 337/400 - Training
# Epoch 337 Training Loss: 0.0097
# Epoch 337 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 338/400 - Training
# Epoch 338 Training Loss: 0.0097
# Epoch 338 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 339/400 - Training
# Epoch 339 Training Loss: 0.0097
# Epoch 339 Validation Loss: 0.0158
# Validation loss did not improve.
#
# Epoch 340/400 - Training
# Epoch 340 Training Loss: 0.0097
# Epoch 340 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 341/400 - Training
# Epoch 341 Training Loss: 0.0097
# Epoch 341 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 342/400 - Training
# Epoch 342 Training Loss: 0.0097
# Epoch 342 Validation Loss: 0.0172
# Validation loss did not improve.
#
# Epoch 343/400 - Training
# Epoch 343 Training Loss: 0.0097
# Epoch 343 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 344/400 - Training
# Epoch 344 Training Loss: 0.0097
# Epoch 344 Validation Loss: 0.0167
# Validation loss did not improve.
#
# Epoch 345/400 - Training
# Epoch 345 Training Loss: 0.0097
# Epoch 345 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 346/400 - Training
# Epoch 346 Training Loss: 0.0097
# Epoch 346 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 347/400 - Training
# Epoch 347 Training Loss: 0.0097
# Epoch 347 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 348/400 - Training
# Epoch 348 Training Loss: 0.0097
# Epoch 348 Validation Loss: 0.0151
# Validation loss did not improve.
#
# Epoch 349/400 - Training
# Epoch 349 Training Loss: 0.0097
# Epoch 349 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 350/400 - Training
# Epoch 350 Training Loss: 0.0097
# Epoch 350 Validation Loss: 0.0147
# Validation loss did not improve.
#
# Epoch 351/400 - Training
# Epoch 351 Training Loss: 0.0097
# Epoch 351 Validation Loss: 0.0150
# Validation loss did not improve.
#
# Epoch 352/400 - Training
# Epoch 352 Training Loss: 0.0097
# Epoch 352 Validation Loss: 0.0158
# Validation loss did not improve.
#
# Epoch 353/400 - Training
# Epoch 353 Training Loss: 0.0097
# Epoch 353 Validation Loss: 0.0160
# Validation loss did not improve.
#
# Epoch 354/400 - Training
# Epoch 354 Training Loss: 0.0097
# Epoch 354 Validation Loss: 0.0170
# Validation loss did not improve.
#
# Epoch 355/400 - Training
# Epoch 355 Training Loss: 0.0097
# Epoch 355 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 356/400 - Training
# Epoch 356 Training Loss: 0.0097
# Epoch 356 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 357/400 - Training
# Epoch 357 Training Loss: 0.0096
# Epoch 357 Validation Loss: 0.0175
# Validation loss did not improve.
#
# Epoch 358/400 - Training
# Epoch 358 Training Loss: 0.0097
# Epoch 358 Validation Loss: 0.0136
# Validation loss did not improve.
#
# Epoch 359/400 - Training
# Epoch 359 Training Loss: 0.0096
# Epoch 359 Validation Loss: 0.0155
# Validation loss did not improve.
#
# Epoch 360/400 - Training
# Epoch 360 Training Loss: 0.0096
# Epoch 360 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 361/400 - Training
# Epoch 361 Training Loss: 0.0097
# Epoch 361 Validation Loss: 0.0145
# Validation loss did not improve.
#
# Epoch 362/400 - Training
# Epoch 362 Training Loss: 0.0096
# Epoch 362 Validation Loss: 0.0148
# Validation loss did not improve.
#
# Epoch 363/400 - Training
# Epoch 363 Training Loss: 0.0097
# Epoch 363 Validation Loss: 0.0157
# Validation loss did not improve.
#
# Epoch 364/400 - Training
# Epoch 364 Training Loss: 0.0096
# Epoch 364 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 365/400 - Training
# Epoch 365 Training Loss: 0.0096
# Epoch 365 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 366/400 - Training
# Epoch 366 Training Loss: 0.0097
# Epoch 366 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 367/400 - Training
# Epoch 367 Training Loss: 0.0096
# Epoch 367 Validation Loss: 0.0140
# Validation loss did not improve.
#
# Epoch 368/400 - Training
# Epoch 368 Training Loss: 0.0097
# Epoch 368 Validation Loss: 0.0135
# Validation loss did not improve.
#
# Epoch 369/400 - Training
# Epoch 369 Training Loss: 0.0096
# Epoch 369 Validation Loss: 0.0149
# Validation loss did not improve.
#
# Epoch 370/400 - Training
# Epoch 370 Training Loss: 0.0096
# Epoch 370 Validation Loss: 0.0143
# Validation loss did not improve.
#
# Epoch 371/400 - Training
# Epoch 371 Training Loss: 0.0096
# Epoch 371 Validation Loss: 0.0153
# Validation loss did not improve.
#
# Epoch 372/400 - Training
# Epoch 372 Training Loss: 0.0096
# Epoch 372 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 373/400 - Training
# Epoch 373 Training Loss: 0.0096
# Epoch 373 Validation Loss: 0.0144
# Validation loss did not improve.
#
# Epoch 374/400 - Training
# Epoch 374 Training Loss: 0.0096
# Epoch 374 Validation Loss: 0.0160
# Validation loss did not improve.
#
# Epoch 375/400 - Training
# Epoch 375 Training Loss: 0.0096
# Epoch 375 Validation Loss: 0.0211
# Validation loss did not improve.
#
# Epoch 376/400 - Training
# Epoch 376 Training Loss: 0.0096
# Epoch 376 Validation Loss: 0.0145
# Validation loss did not improve.
#
# Epoch 377/400 - Training
# Epoch 377 Training Loss: 0.0096
# Epoch 377 Validation Loss: 0.0144
# ...
# Validation loss did not improve.
#
# Epoch 277/400 - Training
# Epoch 277 Training Loss: 0.0100
# Epoch 277 Validation Loss: 0.0117
# Validation loss did not improve.
#
# Epoch 278/400 - Training
# Epoch 278 Training Loss: 0.0100
# Epoch 278 Validation Loss: 0.0122
# Validation loss did not improve.
#
# Epoch 279/400 - Training
# Epoch 279 Training Loss: 0.0100
# Epoch 279 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 280/400 - Training
# Epoch 280 Training Loss: 0.0100
# Epoch 280 Validation Loss: 0.0117
# Validation loss did not improve.
#
# Epoch 281/400 - Training
# Epoch 281 Training Loss: 0.0100
# Epoch 281 Validation Loss: 0.0119
# Validation loss did not improve.
#
# Epoch 282/400 - Training
# Epoch 282 Training Loss: 0.0100
# Epoch 282 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 283/400 - Training
# Epoch 283 Training Loss: 0.0100
# Epoch 283 Validation Loss: 0.0124
# Validation loss did not improve.
#
# Epoch 284/400 - Training
# Epoch 284 Training Loss: 0.0100
# Epoch 284 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 285/400 - Training
# Epoch 285 Training Loss: 0.0100
# Epoch 285 Validation Loss: 0.0131
# Validation loss did not improve.
#
# Epoch 286/400 - Training
# Epoch 286 Training Loss: 0.0099
# Epoch 286 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 287/400 - Training
# Epoch 287 Training Loss: 0.0100
# Epoch 287 Validation Loss: 0.0145
# Validation loss did not improve.
#
# Epoch 288/400 - Training
# Epoch 288 Training Loss: 0.0100
# Epoch 288 Validation Loss: 0.0181
# Validation loss did not improve.
#
# Epoch 289/400 - Training
# Epoch 289 Training Loss: 0.0100
# Epoch 289 Validation Loss: 0.0115
# Validation loss did not improve.
#
# Epoch 290/400 - Training
# Epoch 290 Training Loss: 0.0100
# Epoch 290 Validation Loss: 0.0120
# Validation loss did not improve.
#
# Epoch 291/400 - Training
# Epoch 291 Training Loss: 0.0100
# Epoch 291 Validation Loss: 0.0123
# Validation loss did not improve.
#
# Epoch 292/400 - Training
# Epoch 292 Training Loss: 0.0099
# Epoch 292 Validation Loss: 0.0116
# Validation loss did not improve.
#
# Epoch 293/400 - Training
# Epoch 293 Training Loss: 0.0099
# Epoch 293 Validation Loss: 0.0118
# Validation loss did not improve.
#
# Epoch 294/400 - Training
# Epoch 294 Training Loss: 0.0099
# Epoch 294 Validation Loss: 0.0119
# Validation loss did not improve.
#
# Epoch 295/400 - Training
# Epoch 295 Training Loss: 0.0099
# Epoch 295 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 296/400 - Training
# Epoch 296 Training Loss: 0.0099
# Epoch 296 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 297/400 - Training
# Epoch 297 Training Loss: 0.0099
# Epoch 297 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 298/400 - Training
# Epoch 298 Training Loss: 0.0099
# Epoch 298 Validation Loss: 0.0120
# Validation loss did not improve.
#
# Epoch 299/400 - Training
# Epoch 299 Training Loss: 0.0099
# Epoch 299 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 300/400 - Training
# Epoch 300 Training Loss: 0.0099
# Epoch 300 Validation Loss: 0.0109
# Validation loss did not improve.
#
# Epoch 301/400 - Training
# Epoch 301 Training Loss: 0.0099
# Epoch 301 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 302/400 - Training
# Epoch 302 Training Loss: 0.0099
# Epoch 302 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 303/400 - Training
# Epoch 303 Training Loss: 0.0099
# Epoch 303 Validation Loss: 0.0122
# Validation loss did not improve.
#
# Epoch 304/400 - Training
# Epoch 304 Training Loss: 0.0099
# Epoch 304 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 305/400 - Training
# Epoch 305 Training Loss: 0.0099
# Epoch 305 Validation Loss: 0.0115
# Validation loss did not improve.
#
# Epoch 306/400 - Training
# Epoch 306 Training Loss: 0.0099
# Epoch 306 Validation Loss: 0.0120
# Validation loss did not improve.
#
# Epoch 307/400 - Training
# Epoch 307 Training Loss: 0.0099
# Epoch 307 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 308/400 - Training
# Epoch 308 Training Loss: 0.0099
# Epoch 308 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 309/400 - Training
# Epoch 309 Training Loss: 0.0099
# Epoch 309 Validation Loss: 0.0110
# Validation loss did not improve.
#
# Epoch 310/400 - Training
# Epoch 310 Training Loss: 0.0099
# Epoch 310 Validation Loss: 0.0125
# Validation loss did not improve.
#
# Epoch 311/400 - Training
# Epoch 311 Training Loss: 0.0099
# Epoch 311 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 312/400 - Training
# Epoch 312 Training Loss: 0.0099
# Epoch 312 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 313/400 - Training
# Epoch 313 Training Loss: 0.0099
# Epoch 313 Validation Loss: 0.0127
# Validation loss did not improve.
#
# Epoch 314/400 - Training
# Epoch 314 Training Loss: 0.0099
# Epoch 314 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 315/400 - Training
# Epoch 315 Training Loss: 0.0099
# Epoch 315 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 316/400 - Training
# Epoch 316 Training Loss: 0.0099
# Epoch 316 Validation Loss: 0.0134
# Validation loss did not improve.
#
# Epoch 317/400 - Training
# Epoch 317 Training Loss: 0.0099
# Epoch 317 Validation Loss: 0.0124
# Validation loss did not improve.
#
# Epoch 318/400 - Training
# Epoch 318 Training Loss: 0.0099
# Epoch 318 Validation Loss: 0.0127
# Validation loss did not improve.
#
# Epoch 319/400 - Training
# Epoch 319 Training Loss: 0.0099
# Epoch 319 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 320/400 - Training
# Epoch 320 Training Loss: 0.0099
# Epoch 320 Validation Loss: 0.0108
# Validation loss did not improve.
#
# Epoch 321/400 - Training
# Epoch 321 Training Loss: 0.0099
# Epoch 321 Validation Loss: 0.0116
# Validation loss did not improve.
#
# Epoch 322/400 - Training
# Epoch 322 Training Loss: 0.0099
# Epoch 322 Validation Loss: 0.0108
# Validation loss did not improve.
#
# Epoch 323/400 - Training
# Epoch 323 Training Loss: 0.0098
# Epoch 323 Validation Loss: 0.0144
# Validation loss did not improve.
#
# Epoch 324/400 - Training
# Epoch 324 Training Loss: 0.0099
# Epoch 324 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 325/400 - Training
# Epoch 325 Training Loss: 0.0098
# Epoch 325 Validation Loss: 0.0108
# Validation loss did not improve.
#
# Epoch 326/400 - Training
# Epoch 326 Training Loss: 0.0098
# Epoch 326 Validation Loss: 0.0121
# Validation loss did not improve.
#
# Epoch 327/400 - Training
# Epoch 327 Training Loss: 0.0098
# Epoch 327 Validation Loss: 0.0109
# Validation loss did not improve.
#
# Epoch 328/400 - Training
# Epoch 328 Training Loss: 0.0098
# Epoch 328 Validation Loss: 0.0132
# Validation loss did not improve.
#
# Epoch 329/400 - Training
# Epoch 329 Training Loss: 0.0098
# Epoch 329 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 330/400 - Training
# Epoch 330 Training Loss: 0.0098
# Epoch 330 Validation Loss: 0.0115
# Validation loss did not improve.
#
# Epoch 331/400 - Training
# Epoch 331 Training Loss: 0.0098
# Epoch 331 Validation Loss: 0.0127
# Validation loss did not improve.
#
# Epoch 332/400 - Training
# Epoch 332 Training Loss: 0.0099
# Epoch 332 Validation Loss: 0.0146
# Validation loss did not improve.
#
# Epoch 333/400 - Training
# Epoch 333 Training Loss: 0.0098
# Epoch 333 Validation Loss: 0.0132
# Validation loss did not improve.
#
# Epoch 334/400 - Training
# Epoch 334 Training Loss: 0.0098
# Epoch 334 Validation Loss: 0.0117
# Validation loss did not improve.
#
# Epoch 335/400 - Training
# Epoch 335 Training Loss: 0.0098
# Epoch 335 Validation Loss: 0.0118
# Validation loss did not improve.
#
# Epoch 336/400 - Training
# Epoch 336 Training Loss: 0.0098
# Epoch 336 Validation Loss: 0.0141
# Validation loss did not improve.
#
# Epoch 337/400 - Training
# Epoch 337 Training Loss: 0.0098
# Epoch 337 Validation Loss: 0.0120
# Validation loss did not improve.
#
# Epoch 338/400 - Training
# Epoch 338 Training Loss: 0.0098
# Epoch 338 Validation Loss: 0.0134
# Validation loss did not improve.
#
# Epoch 339/400 - Training
# Epoch 339 Training Loss: 0.0098
# Epoch 339 Validation Loss: 0.0128
# Validation loss did not improve.
#
# Epoch 340/400 - Training
# Epoch 340 Training Loss: 0.0098
# Epoch 340 Validation Loss: 0.0125
# Validation loss did not improve.
#
# Epoch 341/400 - Training
# Epoch 341 Training Loss: 0.0098
# Epoch 341 Validation Loss: 0.0138
# Validation loss did not improve.
#
# Epoch 342/400 - Training
# Epoch 342 Training Loss: 0.0098
# Epoch 342 Validation Loss: 0.0122
# Validation loss did not improve.
#
# Epoch 343/400 - Training
# Epoch 343 Training Loss: 0.0098
# Epoch 343 Validation Loss: 0.0130
# Validation loss did not improve.
#
# Epoch 344/400 - Training
# Epoch 344 Training Loss: 0.0098
# Epoch 344 Validation Loss: 0.0115
# Validation loss did not improve.
#
# Epoch 345/400 - Training
# Epoch 345 Training Loss: 0.0098
# Epoch 345 Validation Loss: 0.0125
# Validation loss did not improve.
#
# Epoch 346/400 - Training
# Epoch 346 Training Loss: 0.0098
# Epoch 346 Validation Loss: 0.0120
# Validation loss did not improve.
#
# Epoch 347/400 - Training
# Epoch 347 Training Loss: 0.0098
# Epoch 347 Validation Loss: 0.0123
# Validation loss did not improve.
#
# Epoch 348/400 - Training
# Epoch 348 Training Loss: 0.0098
# Epoch 348 Validation Loss: 0.0123
# Validation loss did not improve.
#
# Epoch 349/400 - Training
# Epoch 349 Training Loss: 0.0098
# Epoch 349 Validation Loss: 0.0116
# Validation loss did not improve.
#
# Epoch 350/400 - Training
# Epoch 350 Training Loss: 0.0098
# Epoch 350 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 351/400 - Training
# Epoch 351 Training Loss: 0.0098
# Epoch 351 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 352/400 - Training
# Epoch 352 Training Loss: 0.0098
# Epoch 352 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 353/400 - Training
# Epoch 353 Training Loss: 0.0098
# Epoch 353 Validation Loss: 0.0119
# Validation loss did not improve.
#
# Epoch 354/400 - Training
# Epoch 354 Training Loss: 0.0098
# Epoch 354 Validation Loss: 0.0119
# Validation loss did not improve.
#
# Epoch 355/400 - Training
# Epoch 355 Training Loss: 0.0098
# Epoch 355 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 356/400 - Training
# Epoch 356 Training Loss: 0.0098
# Epoch 356 Validation Loss: 0.0120
# Validation loss did not improve.
#
# Epoch 357/400 - Training
# Epoch 357 Training Loss: 0.0098
# Epoch 357 Validation Loss: 0.0117
# Validation loss did not improve.
#
# Epoch 358/400 - Training
# Epoch 358 Training Loss: 0.0097
# Epoch 358 Validation Loss: 0.0132
# Validation loss did not improve.
#
# Epoch 359/400 - Training
# Epoch 359 Training Loss: 0.0098
# Epoch 359 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 360/400 - Training
# Epoch 360 Training Loss: 0.0098
# Epoch 360 Validation Loss: 0.0122
# Validation loss did not improve.
#
# Epoch 361/400 - Training
# Epoch 361 Training Loss: 0.0098
# Epoch 361 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 362/400 - Training
# Epoch 362 Training Loss: 0.0097
# Epoch 362 Validation Loss: 0.0142
# Validation loss did not improve.
#
# Epoch 363/400 - Training
# Epoch 363 Training Loss: 0.0098
# Epoch 363 Validation Loss: 0.0118
# Validation loss did not improve.
#
# Epoch 364/400 - Training
# Epoch 364 Training Loss: 0.0097
# Epoch 364 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 365/400 - Training
# Epoch 365 Training Loss: 0.0098
# Epoch 365 Validation Loss: 0.0121
# Validation loss did not improve.
#
# Epoch 366/400 - Training
# Epoch 366 Training Loss: 0.0097
# Epoch 366 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 367/400 - Training
# Epoch 367 Training Loss: 0.0098
# Epoch 367 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 368/400 - Training
# Epoch 368 Training Loss: 0.0097
# Epoch 368 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 369/400 - Training
# Epoch 369 Training Loss: 0.0097
# Epoch 369 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 370/400 - Training
# Epoch 370 Training Loss: 0.0097
# Epoch 370 Validation Loss: 0.0121
# Validation loss did not improve.
#
# Epoch 371/400 - Training
# Epoch 371 Training Loss: 0.0097
# Epoch 371 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 372/400 - Training
# Epoch 372 Training Loss: 0.0097
# Epoch 372 Validation Loss: 0.0125
# Validation loss did not improve.
#
# Epoch 373/400 - Training
# Epoch 373 Training Loss: 0.0097
# Epoch 373 Validation Loss: 0.0125
# Validation loss did not improve.
#
# Epoch 374/400 - Training
# Epoch 374 Training Loss: 0.0097
# Epoch 374 Validation Loss: 0.0154
# Validation loss did not improve.
#
# Epoch 375/400 - Training
# Epoch 375 Training Loss: 0.0098
# Epoch 375 Validation Loss: 0.0152
# Validation loss did not improve.
#
# Epoch 376/400 - Training
# Epoch 376 Training Loss: 0.0097
# Epoch 376 Validation Loss: 0.0127
# Validation loss did not improve.
#
# Epoch 377/400 - Training
# Epoch 377 Training Loss: 0.0097
# Epoch 377 Validation Loss: 0.0169
# Validation loss did not improve.
#
# Epoch 378/400 - Training
# Epoch 378 Training Loss: 0.0097
# Epoch 378 Validation Loss: 0.0115
# Validation loss did not improve.
#
# Epoch 379/400 - Training
# Epoch 379 Training Loss: 0.0097
# Epoch 379 Validation Loss: 0.0118
# Validation loss did not improve.
#
# Epoch 380/400 - Training
# Epoch 380 Training Loss: 0.0097
# Epoch 380 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 381/400 - Training
# Epoch 381 Training Loss: 0.0097
# Epoch 381 Validation Loss: 0.0117
# Validation loss did not improve.
#
# Epoch 382/400 - Training
# Epoch 382 Training Loss: 0.0097
# Epoch 382 Validation Loss: 0.0131
# Validation loss did not improve.
#
# Epoch 383/400 - Training
# Epoch 383 Training Loss: 0.0097
# Epoch 383 Validation Loss: 0.0112
# Validation loss did not improve.
#
# Epoch 384/400 - Training
# Epoch 384 Training Loss: 0.0097
# Epoch 384 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 385/400 - Training
# Epoch 385 Training Loss: 0.0097
# Epoch 385 Validation Loss: 0.0121
# Validation loss did not improve.
#
# Epoch 386/400 - Training
# Epoch 386 Training Loss: 0.0097
# Epoch 386 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 387/400 - Training
# Epoch 387 Training Loss: 0.0097
# Epoch 387 Validation Loss: 0.0137
# Validation loss did not improve.
#
# Epoch 388/400 - Training
# Epoch 388 Training Loss: 0.0097
# Epoch 388 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 389/400 - Training
# Epoch 389 Training Loss: 0.0097
# Epoch 389 Validation Loss: 0.0116
# Validation loss did not improve.
#
# Epoch 390/400 - Training
# Epoch 390 Training Loss: 0.0097
# Epoch 390 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Epoch 391/400 - Training
# Epoch 391 Training Loss: 0.0097
# Epoch 391 Validation Loss: 0.0111
# Validation loss did not improve.
#
# Epoch 392/400 - Training
# Epoch 392 Training Loss: 0.0097
# Epoch 392 Validation Loss: 0.0115
# Validation loss did not improve.
#
# Epoch 393/400 - Training
# Epoch 393 Training Loss: 0.0097
# Epoch 393 Validation Loss: 0.0126
# Validation loss did not improve.
#
# Epoch 394/400 - Training
# Epoch 394 Training Loss: 0.0097
# Epoch 394 Validation Loss: 0.0118
# Validation loss did not improve.
#
# Epoch 395/400 - Training
# Epoch 395 Training Loss: 0.0097
# Epoch 395 Validation Loss: 0.0116
# Validation loss did not improve.
#
# Epoch 396/400 - Training
# Epoch 396 Training Loss: 0.0097
# Epoch 396 Validation Loss: 0.0114
# Validation loss did not improve.
#
# Epoch 397/400 - Training
# Epoch 397 Training Loss: 0.0097
# Epoch 397 Validation Loss: 0.0119
# Validation loss did not improve.
#
# Epoch 398/400 - Training
# Epoch 398 Training Loss: 0.0097
# Epoch 398 Validation Loss: 0.0126
# Validation loss did not improve.
#
# Epoch 399/400 - Training
# Epoch 399 Training Loss: 0.0096
# Epoch 399 Validation Loss: 0.0126
# Validation loss did not improve.
#
# Epoch 400/400 - Training
# Epoch 400 Training Loss: 0.0097
# Epoch 400 Validation Loss: 0.0113
# Validation loss did not improve.
#
# Training complete. Best Validation Loss: 0.0107
# Fold 1 Average Validation Loss: 0.0132
# Fold 2 Average Validation Loss: 0.0088
# Fold 3 Average Validation Loss: 0.0117
# Fold 4 Average Validation Loss: 0.0097
# Fold 5 Average Validation Loss: 0.0114
# Fold 6 Average Validation Loss: 0.0126
# Fold 7 Average Validation Loss: 0.0103
# Fold 8 Average Validation Loss: 0.0093
# Fold 9 Average Validation Loss: 0.0107
# Overall Average Validation Loss: 0.0109

# %%
def predict_ensemble(saved_model_paths, test_loader, device, num_timesteps, models, model_seq_lens):
    """
    Generate ensemble predictions by averaging outputs from multiple models.
    """
    ensemble_predictions = []
    ids = [sample['id'] for sample in test_loader.dataset.samples]
    model_output_timesteps = 20  # Number of timesteps each model predicts
    NT = num_timesteps // model_output_timesteps
    remainder = num_timesteps % model_output_timesteps
    total_iterations = NT + (1 if remainder > 0 else 0)
    print(f"Total iterations required: {total_iterations}")

    for idx, inputs in enumerate(tqdm(test_loader, desc="Predicting")):  # Removed target
        input_seq = inputs.to(device)        # [1, 5, 5, 113, 32]

        # Initialize an empty list to store predictions for this sample
        preds_per_id = []

        for t in range(total_iterations):
            ensemble_output = np.zeros((model_output_timesteps, 113, 32), dtype=np.float32)
            model_count = 0  # To count valid models for averaging

            for model, seq_len in zip(models, model_seq_lens):
                with torch.no_grad():
                    selected_seq = input_seq[:, -seq_len:, :, :, :] 
                    output = model(selected_seq) 
                    output = output.view(1, model_output_timesteps, 1, 113, 32)
                    ensemble_output += output.reshape(20, 113, 32).cpu().numpy()
                    model_count += 1

            if model_count == 0:
                raise ValueError("No valid models were processed for averaging.")

            ensemble_output /= model_count  # Averaging over ensemble
            
            if (t == total_iterations - 1) and (remainder > 0):
                ensemble_output = ensemble_output[:remainder]

            preds_per_id.append(ensemble_output.reshape(-1))  
            ensemble_output_tensor = torch.from_numpy(ensemble_output).unsqueeze(0).to(device)  
            num_new_timesteps = ensemble_output_tensor.shape[1]  
            new_time_steps = input_seq[:, -1, :, :, :].unsqueeze(1).repeat(1, num_new_timesteps, 1, 1, 1).clone()
            new_time_steps[:, :, 2, :, :] = ensemble_output_tensor 
            input_seq = torch.cat([input_seq, new_time_steps], dim=1)  
            input_seq = input_seq[:, -seq_len:, :, :, :]

        preds_flat = np.concatenate(preds_per_id)  
        ensemble_predictions.append(preds_flat)
        
    return ensemble_predictions, ids

# %%
# !pip freeze > requirements.txt

# %%
def prepare_submission(predictions, ids, submission_csv, num_timesteps=20):
    """
    Prepares the submission CSV file from predictions and IDs.

    Args:
        predictions (list): List of numpy arrays containing predictions for each test sample.
        ids (list): List of sample IDs corresponding to the predictions.
        submission_csv (str): Path to save the submission CSV.
        num_timesteps (int): Number of future timesteps predicted.

    Returns:
        None
    """
    print("Preparing submission file...")
    submission = pd.DataFrame(predictions)
    submission.insert(0, 'id', ids)
    expected_pixels = 113 * 32 * num_timesteps  # 72,320 for 20 timesteps
    submission.columns = ['id'] + [f'pixel_{i}' for i in range(1, submission.shape[1])]
    assert submission.shape == (len(predictions), 1 + expected_pixels), f"Expected shape ({len(predictions)}, {1 + expected_pixels}), got {submission.shape}"
    submission.to_csv(submission_csv, index=False)
    print(f'Submission file saved as {submission_csv}')

# %%
import os

def parse_model_path(model_path):
    """
    Parses the model path to extract encoder_name and fold.
    Assumes the model_path format: 'model_<encoder_name>_fold<fold>.pth'
    Example: 'model_residualcnn_fold1.pth'
    """
    filename = os.path.basename(model_path)
    parts = filename.split('_')

    if len(parts) < 3:
        raise ValueError(f"Unexpected model filename format: {filename}")

    encoder_name = parts[1]

    # Extract fold
    fold_part = parts[2]  # e.g., 'fold1.pth'
    fold_str = fold_part.split('.')[0]  # 'fold1'
    fold = int(fold_str.replace('fold', ''))

    # Define sequence length (seq_len) based on encoder_name using a predefined mapping
    encoder_seq_len_mapping = {
        'residualcnn': 5,
        'residualcnnsa': 5,
        'convlstm': 5,
        'selfattconvlstm': 5,
        '3dconvlstm': 5,
        'dconvlstmsac': 5,
        'bidirectconvlstmunet': 5,
        'attentionunet': 5,
        'deeplabtemporal': 5,
        'unet': 5,
        'residualdensecnn': 5,
        'multiscaleconvlstm': 5,
    }

    if encoder_name not in encoder_seq_len_mapping:
        raise ValueError(f"Unknown encoder_name '{encoder_name}', cannot determine seq_len.")

    seq_len = encoder_seq_len_mapping[encoder_name]

    return encoder_name, fold, seq_len

# %%
test_dataset = FireDataset(
        csv_data=test_csv,
        data_dir=test_data_dir,
        seq_len=SEQ_LEN,
        multi_step=NUM_STEPS,
        is_train=False
    )

test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=1,  # Typically batch_size=1 for test predictions
    shuffle=False,
    num_workers=0,
    pin_memory=True,
    worker_init_fn=seed_worker,
)

models = []
model_seq_lens = []

# Load saved models - load state_dicts
for model_path in saved_model_paths:
    try:
        encoder_name, fold, seq_len = parse_model_path(model_path)
    except ValueError as e:
        print(f"Skipping model {model_path}: {e}")
        continue

    print(f"Loading model: {model_path}, Encoder: {encoder_name}, Fold: {fold}, Seq_len: {seq_len}")

    # Initialize the model with the correct in_channels based on seq_len
    in_channels = seq_len * 5  # 5 channels per time step

    if encoder_name == 'residualcnn':
        model = ResidualCNN(in_channels=in_channels, num_residual_blocks=4).to(device)

    # Load state_dict
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    
    models.append(model)
    model_seq_lens.append(seq_len)  # Store the seq_len for this model

# Generate Ensemble Predictions
ensemble_predictions, ids = predict_ensemble(
    saved_model_paths=saved_model_paths,
    test_loader=test_loader,
    device=device,
    num_timesteps=NUM_STEPS,
    models=models,
    model_seq_lens=model_seq_lens
)


# Prepare Submission File
prepare_submission(
    predictions=ensemble_predictions, 
    ids=ids, 
    submission_csv='submission.csv', 
    num_timesteps=NUM_STEPS
)
# Out:
# /tmp/ipykernel_24/689755127.py:38: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# Loading model: model_residualcnn_fold1.pth, Encoder: residualcnn, Fold: 1, Seq_len: 5
# Loading model: model_residualcnn_fold2.pth, Encoder: residualcnn, Fold: 2, Seq_len: 5
# Loading model: model_residualcnn_fold3.pth, Encoder: residualcnn, Fold: 3, Seq_len: 5
# Loading model: model_residualcnn_fold4.pth, Encoder: residualcnn, Fold: 4, Seq_len: 5
# Loading model: model_residualcnn_fold5.pth, Encoder: residualcnn, Fold: 5, Seq_len: 5
# Loading model: model_residualcnn_fold6.pth, Encoder: residualcnn, Fold: 6, Seq_len: 5
# Loading model: model_residualcnn_fold7.pth, Encoder: residualcnn, Fold: 7, Seq_len: 5
# Loading model: model_residualcnn_fold8.pth, Encoder: residualcnn, Fold: 8, Seq_len: 5
# Loading model: model_residualcnn_fold9.pth, Encoder: residualcnn, Fold: 9, Seq_len: 5
# Total iterations required: 1
# Predicting: 100%|██████████| 27/27 [00:00<00:00, 73.63it/s]
# Preparing submission file...
# Submission file saved as submission.csv
